# %%
import pandas as pd
import numpy as np
import random as rm
import matplotlib.pyplot as plt
from markovchain import MarkovChain
from pandas import read_csv

# %%
df=pd.read_csv("multi_data.csv")

# %%
df.columns
# Out:
# Index(['Date ', 'Id', 'Age', 'time ', 'SpO2', 'HR', 'ABP (S)', 'ABP (D)',
#        'ABP (M)', 'Temp', 'CVP', 'Mode of vent', 'vent Rate', 'TV', 'PIP',
#        'PEEP', 'MAP', 'Ti', 'FiO2', 'PaO2/FiO2', 'ABG/VBG', 'PH', 'PCO2',
#        'PO2', 'HCO3', 'BE', 'Hb%', 'Na', 'K', 'Cl', 'Anion gap(Na+K -Cl)',
#        'AaDO2', 'Lact', 'Ca', 'Glu', 'Urine', 'Hr T drain', 'Transfus',
#        'Dobu dial ', 'Milri', 'Nor epi', 'Inotrop score', 'VIS', 'Amiodaron',
#        'Lasix', 'Total intake', 'Total balance '],
#       dtype='object')

# %%
tmp_df = df[df.Id == df.Id[0]]

# %%
tmp_df['time '] = tmp_df['time '].str.split(':').apply(lambda x: ':'.join(x[:2]))
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp_df['datetime'] = tmp_df['Date '] + ' ' + tmp_df['time ']
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp_df['datetime'] = pd.to_datetime(tmp_df['datetime'], format='%d.%m.%Y %H:%M')
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp_df.drop(['Date ', 'time '], axis=1, inplace=True)
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
tmp_df = tmp_df.sort_values('datetime')

# %%
tmp_df.head(50)
# Out:
#            Id  Age  SpO2   HR  ABP (S)  ABP (D)  ABP (M)   Temp  CVP  \
# 16  371500-18   12    98  118       51       34       41   98.0    8
# 17  371500-18   12    98  120       75       43       54   98.0   11
# 18  371500-18   12    97  126       66       36       46   98.0    9
# 19  371500-18   12    98  125       57       35       43   98.0   11
# 20  371500-18   12    98  134       91       51       65   98.0   15
# 21  371500-18   12   100  142       80       46       58   98.0   11
# 22  371500-18   12   100  145       76       43       54   98.0   13
# 23  371500-18   12   100  140       63       41       49   98.0   10
# 0   371500-18   12    90   97       36       24       41   98.0    0
# 1   371500-18   12    90   97       36       24       41   98.0    0
# 2   371500-18   12    90   97       36       24       41   98.0    0
# 3   371500-18   12    90   97       36       24       41   98.0    0
# 4   371500-18   12    90   97       36       24       41   98.0    0
# 5   371500-18   12    90   97       36       24       41   98.0    0
# 6   371500-18   12    90   97       36       24       41   98.0    0
# 7   371500-18   12    98  135      120       73       91   98.0    6
# 8   371500-18   12   100  129      120       80       95   98.0    9
# 9   371500-18   12   100  115       96       60       74   98.0    7
# 10  371500-18   12   100  111       92       58       71   98.0    7
# 11  371500-18   12   100  111       92       59       72   98.0    7
# 12  371500-18   12    98  116       78       50       61   98.0    7
# 13  371500-18   12    99  117       83       52       63   98.0    8
# 14  371500-18   12    98  119       64       40       49   98.0    6
# 15  371500-18   12   100  121       63       40       48   98.0    8
# 40  371500-18   12    97  146       82       43       53   98.0   11
# 41  371500-18   12    96  137       69       39       52   98.0   11
# 42  371500-18   12    95  131       71       38       48   98.0   11
# 43  371500-18   12    96  130       60       38       48   98.0   11
# 44  371500-18   12    96  132       64       24       43   98.0   11
# 45  371500-18   12    97  133       65       25       45   98.0   11
# 46  371500-18   12    97  133       65       36       45   98.0   11
# 47  371500-18   12    97  133       61       36       44   98.0   11
# 24  371500-18   12   100  138       76       44       55   98.0    8
# 25  371500-18   12   100  143       83       44       57   98.0   11
# 26  371500-18   12    93  127       74       39       51   98.0   13
# 27  371500-18   12    95  129       73       42       53   98.0   12
# 28  371500-18   12    95  130       71       42       52   98.0   13
# 29  371500-18   12    95  138       70       42       51   98.0   14
# 30  371500-18   12    95  132       63       45       53   98.0   12
# 31  371500-18   12    94  128       71       40       50   98.0    9
# 32  371500-18   12    97  130       73       43       56   98.0   15
# 33  371500-18   12    96  130       62       37       45   98.0   13
# 34  371500-18   12    96  132       57       36       45   98.0   13
# 35  371500-18   12    96  134       54       36       43   98.0   14
# 36  371500-18   12    96  133       66       34       42   98.0    6
# 37  371500-18   12    96  135       76       38       49   98.0   14
# 38  371500-18   12    97  150       70       40       51  100.0   12
# 39  371500-18   12    96  149       77       39       48   98.0   11
# 64  371500-18   12    98  146       65       40       50   98.0    0
# 65  371500-18   12    98  143       72       43       53   98.0    6
#
#    Mode of vent  ...  Dobu dial   Milri  Nor epi  Inotrop score  VIS  \
# 16     PRVC/CMV  ...         1.8    0.9      0.1            NaN  NaN
# 17     PRVC/CMV  ...         1.8    0.9      0.1            NaN  NaN
# 18     PRVC/CMV  ...         1.8    0.9      0.1            NaN  NaN
# 19     PRVC/CMV  ...         1.8    0.9      0.5            NaN  NaN
# 20     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 21     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 22    PRVC/SIMV  ...         1.8    0.9      2.1            NaN  NaN
# 23    PRVC/SIMV  ...         1.8    0.9      2.1            NaN  NaN
# 0      PRVC/CMV  ...         0.2    0.2      0.1            NaN  NaN
# 1      PRVC/CMV  ...         0.2    0.2      0.1            NaN  NaN
# 2      PRVC/CMV  ...         0.2    0.2      0.1            NaN  NaN
# 3      PRVC/CMV  ...         0.2    0.2      0.1            NaN  NaN
# 4      PRVC/CMV  ...         0.2    0.2      0.1            NaN  NaN
# 5      PRVC/CMV  ...         0.2    0.2      0.1            NaN  NaN
# 6      PRVC/CMV  ...         0.2    0.2      0.1            NaN  NaN
# 7      PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 8      PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 9      PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 10     PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 11     PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 12     PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 13     PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 14     PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 15     PRVC/CMV  ...         1.8    1.7      0.1            NaN  NaN
# 40     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 41     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 42     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 43     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 44     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 45     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 46     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 47     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 24    PRVC/SIMV  ...         1.8    0.9      2.1            NaN  NaN
# 25    PRVC/SIMV  ...         1.8    0.9      2.1            NaN  NaN
# 26           PS  ...         1.8    0.9      2.1            NaN  NaN
# 27    PRVC/SIMV  ...         1.8    0.9      2.1            NaN  NaN
# 28     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 29     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 30     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 31     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 32     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 33     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 34     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 35     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 36     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 37     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 38     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 39     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 64     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
# 65     PRVC/CMV  ...         1.8    0.9      2.1            NaN  NaN
#
#     Amiodaron  Lasix  Total intake Total balance             datetime
# 16        NaN    0.5         183.2            8.2 2018-02-26 00:30:00
# 17        NaN    0.5         197.4           17.4 2018-02-26 01:30:00
# 18        NaN    0.5         211.6            9.6 2018-02-26 02:30:00
# 19        NaN    0.5         228.1           19.1 2018-02-26 03:30:00
# 20        NaN    0.5         246.2           22.2 2018-02-26 04:30:00
# 21        NaN    0.5         261.0           32.0 2018-02-26 05:30:00
# 22        NaN    0.5         275.8           42.8 2018-02-26 06:30:00
# 23        NaN    0.5         290.6           53.6 2018-02-26 07:30:00
# 0         NaN    0.5           1.0         -508.6 2018-02-26 08:30:00
# 1         NaN    0.5           1.0         -508.6 2018-02-26 09:30:00
# 2         NaN    0.5           1.0         -508.6 2018-02-26 10:30:00
# 3         NaN    0.5           1.0         -508.6 2018-02-26 11:30:00
# 4         NaN    0.5           1.0         -508.6 2018-02-26 12:30:00
# 5         NaN    0.5           1.0         -508.6 2018-02-26 13:30:00
# 6         NaN    0.5           1.0         -508.6 2018-02-26 14:30:00
# 7         NaN    0.5          16.0           -9.0 2018-02-26 15:30:00
# 8         NaN    0.5          32.0          -13.0 2018-02-26 16:30:00
# 9         NaN    0.5          48.0           -7.0 2018-02-26 17:30:00
# 10        NaN    0.5          63.0           -7.0 2018-02-26 18:30:00
# 11        NaN    0.5          78.0           -2.0 2018-02-26 19:30:00
# 12        NaN    0.5          93.0          -22.0 2018-02-26 20:30:00
# 13        NaN    0.5         108.0          -17.0 2018-02-26 21:30:00
# 14        NaN    0.5         124.8          -40.2 2018-02-26 22:30:00
# 15        NaN    0.5         139.0          -31.0 2018-02-26 23:30:00
# 40        NaN    1.0         386.7          187.7 2018-02-27 00:30:00
# 41        NaN    1.0         404.8          170.8 2018-02-27 01:30:00
# 42        NaN    1.0         422.9          178.9 2018-02-27 02:30:00
# 43        NaN    1.0         441.0          182.0 2018-02-27 03:30:00
# 44        NaN    1.0         459.1          180.1 2018-02-27 04:30:00
# 45        NaN    1.0         477.2          188.2 2018-02-27 05:30:00
# 46        NaN    1.0         510.3          211.3 2018-02-27 06:30:00
# 47        NaN    1.0         528.4          214.4 2018-02-27 07:30:00
# 24        NaN    0.5          14.8            9.8 2018-02-27 08:30:00
# 25        NaN    0.5          31.4           21.4 2018-02-27 09:30:00
# 26        NaN    0.5          48.0           35.0 2018-02-27 10:30:00
# 27        NaN    1.0          62.8           19.8 2018-02-27 11:30:00
# 28        NaN    1.0          87.6           44.6 2018-02-27 12:30:00
# 29        NaN    1.0         132.4           79.4 2018-02-27 13:30:00
# 30        NaN    1.0         149.7           81.7 2018-02-27 14:30:00
# 31        NaN    1.0         167.0           89.0 2018-02-27 15:30:00
# 32        NaN    1.0         184.3           91.3 2018-02-27 16:30:00
# 33        NaN    1.0         217.4           99.4 2018-02-27 17:30:00
# 34        NaN    1.0         237.3          114.3 2018-02-27 18:30:00
# 35        NaN    1.0         272.2          144.2 2018-02-27 19:30:00
# 36        NaN    1.0         292.1          159.1 2018-02-27 20:30:00
# 37        NaN    1.0         312.0          173.0 2018-02-27 21:30:00
# 38        NaN    1.0         331.9          167.9 2018-02-27 22:30:00
# 39        NaN    1.0         351.8          172.8 2018-02-27 23:30:00
# 64        NaN    1.0         380.5          -34.5 2018-02-28 00:30:00
# 65        NaN    1.0         399.9          -30.1 2018-02-28 01:30:00
#
# [50 rows x 46 columns]

# %%
def create_state(value):
    cvp_value = value['CVP']
    urine_value = value['Urine']
    age_value = value['Age']
    bp_value = value['ABP (S)']
    
    if ((8 < cvp_value < 13) and (80 <= bp_value <= 120) and (((age_value <= 12) and (urine_value > 2)) or ((age_value > 12) and (urine_value > 1)))):
        return 'Imporovement'
    elif (((cvp_value < 8) or (cvp_value > 13)) and (bp_value < 70) and (((age_value <= 12) and (urine_value < 2)) or ((age_value > 12) and (urine_value < 1)))):
        return 'Detroite'
    else:
        return 'Stable'

# %%
# tmp_df['state'] = tmp_df['value'].apply(create_state)
tmp_df['state'] = tmp_df.apply(create_state, axis=1)

# %%
# df['state'] = df.apply(create_state, axis=1)
tmp_df.head(10)
# Out:
#            Id  Age  SpO2   HR  ABP (S)  ABP (D)  ABP (M)  Temp  CVP  \
# 16  371500-18   12    98  118       51       34       41  98.0    8
# 17  371500-18   12    98  120       75       43       54  98.0   11
# 18  371500-18   12    97  126       66       36       46  98.0    9
# 19  371500-18   12    98  125       57       35       43  98.0   11
# 20  371500-18   12    98  134       91       51       65  98.0   15
# 21  371500-18   12   100  142       80       46       58  98.0   11
# 22  371500-18   12   100  145       76       43       54  98.0   13
# 23  371500-18   12   100  140       63       41       49  98.0   10
# 0   371500-18   12    90   97       36       24       41  98.0    0
# 1   371500-18   12    90   97       36       24       41  98.0    0
#
#    Mode of vent  ...  Milri  Nor epi  Inotrop score  VIS  Amiodaron  Lasix  \
# 16     PRVC/CMV  ...    0.9      0.1            NaN  NaN        NaN    0.5
# 17     PRVC/CMV  ...    0.9      0.1            NaN  NaN        NaN    0.5
# 18     PRVC/CMV  ...    0.9      0.1            NaN  NaN        NaN    0.5
# 19     PRVC/CMV  ...    0.9      0.5            NaN  NaN        NaN    0.5
# 20     PRVC/CMV  ...    0.9      2.1            NaN  NaN        NaN    0.5
# 21     PRVC/CMV  ...    0.9      2.1            NaN  NaN        NaN    0.5
# 22    PRVC/SIMV  ...    0.9      2.1            NaN  NaN        NaN    0.5
# 23    PRVC/SIMV  ...    0.9      2.1            NaN  NaN        NaN    0.5
# 0      PRVC/CMV  ...    0.2      0.1            NaN  NaN        NaN    0.5
# 1      PRVC/CMV  ...    0.2      0.1            NaN  NaN        NaN    0.5
#
#     Total intake  Total balance             datetime         state
# 16         183.2             8.2 2018-02-26 00:30:00        Stable
# 17         197.4            17.4 2018-02-26 01:30:00        Stable
# 18         211.6             9.6 2018-02-26 02:30:00        Stable
# 19         228.1            19.1 2018-02-26 03:30:00        Stable
# 20         246.2            22.2 2018-02-26 04:30:00        Stable
# 21         261.0            32.0 2018-02-26 05:30:00  Imporovement
# 22         275.8            42.8 2018-02-26 06:30:00        Stable
# 23         290.6            53.6 2018-02-26 07:30:00        Stable
# 0            1.0          -508.6 2018-02-26 08:30:00      Detroite
# 1            1.0          -508.6 2018-02-26 09:30:00      Detroite
#
# [10 rows x 47 columns]

# %%
state_dict = {'Imporovement': 0, 'Stable': 1, 'Detroite':2}

# %%
tmp_df['state'] = tmp_df['state'].apply(lambda x: state_dict.get(x))

# %%
def transition_matrix(transitions):
    
    n = 1+ max(transitions) #number of states

    M = [[0]*n for _ in range(n)]

    for (i,j) in zip(transitions,transitions[1:]):
        M[i][j] += 1

    #now convert to probabilities:
    for row in M:
        s = sum(row)
        if s > 0:
            row[:] = [f/s for f in row]
    return M

# %%
# transitionMatrix = transition_matrix(tmp_df['state'])
transitionMatrix = np.array(transition_matrix(tmp_df['state']))

# %%
print("Transition Matrix:")
transitionMatrix
# Out:
# Transition Matrix:
# array([[0.575     , 0.425     , 0.        ],
#        [0.12878788, 0.84848485, 0.02272727],
#        [0.        , 0.02197802, 0.97802198]])

# %%
mc = MarkovChain(transitionMatrix, ['Improv', 'Stable', 'Detrio'])
print("MarkovChain Transition Matrix Graph:")
mc.draw()
# Out:
# MarkovChain Transition Matrix Graph:

# %%
# The statespace
states = ["Improvement","Deteriorate","Stable"]

# Possible sequences of events
transitionName = [["II","IS","ID"],["DI","DS","DD"],["SI","SS","SD"]]

# %%
if sum(transitionMatrix[0]) +sum(transitionMatrix[1])+sum(transitionMatrix[1]) != 3:
    print("Somewhere, something went wrong. Transition matrix, perhaps?")
    
else: print("All is gonna be okay, you should move on!!")
# Out:
# All is gonna be okay, you should move on!!

# %%
#for starting state improvement
#A function that implements the Markov model to forecast the state/mood.
def activity_forecast(days):
    II=transitionMatrix[0,0]
    IS=transitionMatrix[0,1]
    ID=transitionMatrix[0,2]
    SI=transitionMatrix[1,0]
    SS=transitionMatrix[1,1]
    SD=transitionMatrix[1,2]
    DI=transitionMatrix[2,0]
    DS=transitionMatrix[2,1]
    DD=transitionMatrix[2,2]
    
    # Choose the starting state
    activityToday = "Stable"
    print("Start state: " + activityToday)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    activityList = [activityToday]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    while i != days:
        if activityToday == "Improvement":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "II":
                prob = prob * II
                activityList.append("Improvement")
                pass
            elif change == "IS":
                prob = prob * IS
                activityToday = "Stable"
                activityList.append("Stable")
            else:
                prob = prob * ID
                activityToday = "Deteriorate"
                activityList.append("Deteriorate")
        elif activityToday == "Stable":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "SS":
                prob = prob * SS
                activityList.append("Stable")
                pass
            elif change == "SI":
                prob = prob * SI
                activityToday = "Improvement"
                activityList.append("Improvement")
            else:
                prob = prob * SD
                activityToday = "Deteriorate"
                activityList.append("Deteriorate")
        elif activityToday == "Deteriorate":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "DD":
                prob = prob * DD
                activityList.append("Deteriorate")
                pass
            elif change == "DI":
                prob = prob * DI
                activityToday = "Improvement"
                activityList.append("Improvement")
            else:
                prob = prob * DS
                activityToday = "Stable"
                activityList.append("Stable")
        i += 1  
    print("Possible states: " + str(activityList))
    print("End state after "+ str(days) + " days: " + activityToday)
    print("Probability of the possible sequence of states: " + str(prob))

# Function that forecasts the possible state for the next 2 days or 48 hours
activity_forecast(2)
# Out:
# Start state: Stable
# Possible states: ['Stable', 'Deteriorate', 'Stable']
# End state after 2 days: Stable
# Probability of the possible sequence of states: 0.0004995004995004995

# %%
# A functions which implements the Markov model to forecast the patient
def activity_forecast(days):
    II=transitionMatrix[0,0]
    IS=transitionMatrix[0,1]
    ID=transitionMatrix[0,2]
    SI=transitionMatrix[1,0]
    SS=transitionMatrix[1,1]
    SD=transitionMatrix[1,2]
    DI=transitionMatrix[2,0]
    DS=transitionMatrix[2,1]
    DD=transitionMatrix[2,2]
    # Choose the starting state
    activityToday = "Stable"
#     print("Start state: " + activityToday)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    activityList = [activityToday]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    while i != days:
        if activityToday == "Improvement":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "II":
                prob = prob * II
                activityList.append("Improvement")
                pass
            elif change == "IS":
                prob = prob * IS
                activityToday = "Stable"
                activityList.append("Stable")
            else:
                prob = prob * ID
                activityToday = "Deteriorate"
                activityList.append("Deteriorate")
        elif activityToday == "Stable":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "SS":
                prob = prob * SS
                activityList.append("Stable")
                pass
            elif change == "SI":
                prob = prob * SI
                activityToday = "Improvement"
                activityList.append("Improvement")
            else:
                prob = prob * SD
                activityToday = "Deteriorate"
                activityList.append("Deteriorate")
        elif activityToday == "Deteriorate":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "DD":
                prob = prob * DD
                activityList.append("Deteriorate")
                pass
            elif change == "DI":
                prob = prob * DI
                activityToday = "Improvement"
                activityList.append("Improvement")
            else:
                prob = prob * DS
                activityToday = "Stable"
                activityList.append("Stable")
        i += 1     
    return activityList

# To save every activityList 
list_activity = []
count = 0

# `Range` starts from the first count up until but excluding the last count
for iterations in range(1,10000):
        list_activity.append(activity_forecast(2))

# Check out all the `activityList` we collected    
print(list_activity)

# Iterate through the list to get a count of all activities ending in state:'Stable'
for smaller_list in list_activity:
    if(smaller_list[2] == "Stable"):
        count += 1

# Calculate the probability of starting from state:'Improvement' and ending at state:'Stable'
percentage = (count/10000) * 100
print("The probability of starting state to ending state after 48 hours: " + str(percentage) + "%")
# Out:
# [['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['Stable', 'Deteriorate', 'Stable'], ['S ...
# The probability of starting state to ending state after 48 hours: 99.99%
